# %% [markdown]
# ## CRBM

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from time import time

from crbm.rbm import CRBM
# Import our RBM
from crbm.rbm import CRBM

# %%
# Function for reading data file
import struct
def read_idx(filename):
    with open(filename, 'rb') as f:
        zero, data_type, dims = struct.unpack('>HBB', f.read(4))
        shape = tuple(struct.unpack('>I', f.read(4))[0] for d in range(dims))
        return np.frombuffer(f.read(), dtype=np.uint8).reshape(shape)

# %%
X_test = read_idx("data/MNIST/raw/t10k-images-idx3-ubyte").reshape(-1, 28*28)
X = read_idx("data/MNIST/raw/train-images-idx3-ubyte").reshape(-1, 28*28)
y_test = read_idx("data/MNIST/raw/t10k-labels-idx1-ubyte")
y = read_idx("data/MNIST/raw/train-labels-idx1-ubyte")

# EXTREMELY IMPORTANT TO NORMALIZE
X = np.true_divide(X, 255)
X_test = np.true_divide(X_test, 255)

# %%
# Some hand picked images for each class for plotting
selected_imgs = X[[1, 6, 5, 12, 26, 35, 62, 52, 46, 4]]

# %%
# Train-val split
split = 0.1
indices = np.arange(len(X))
np.random.shuffle(indices)
X_val = X[:int(split*X.shape[0])]
X_train = X[int(split*X.shape[0]):]
y_val = y[:int(split*X.shape[0])]
y_train = y[int(split*X.shape[0]):]
print("Number of training instances:\t", y_train.shape[0])
print("Number of validation instances:\t", y_val.shape[0])
print("Number of test instances:\t", y_test.shape[0])
# Out:
# Number of training instances:	 54000
# Number of validation instances:	 6000
# Number of test instances:	 10000

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
print("Number of training instances:\t", y_train.shape[0])
print("Number of validation instances:\t", y_val.shape[0])
print("Number of test instances:\t", y_test.shape[0])
# Out:
# Number of training instances:	 54000
# Number of validation instances:	 6000
# Number of test instances:	 10000

# %%
def KL(P, Q):
    epsilon = 1e-10
    P = np.clip(P, epsilon, 1)
    Q = np.clip(Q, epsilon, 1)
    return np.sum(P * np.log(P / Q))

# %%
def get_batches(data, batch_size, shuffle=False):
    '''
    Function to provide data in batches.
    input:
        - data: The data to be batched, each sample in one row.
        - batch_size: Size of one batch (last batch might be smaller)
        - shuffle: True if data should be shuffled.
    '''
    if(shuffle):
        np.random.shuffle(data)
    if(batch_size == -1):
        batch_size = len(data)
    num_batches = math.ceil(data.shape[0]/batch_size)
    for batch_num in range(num_batches):
        yield data[batch_num*batch_size:(batch_num+1)*batch_size]

# %%
# Some parameters to set
batch_size = 50
num_epochs = 100
lr = 0.1
burn_in = 0
num_steps = 1

# %% [markdown]
# Def of the model

# %%
model = CRBM(v_dim=X_train.shape[-1], h_dim=100)

# %%
crbm_dkl_per_epoch = []

# %%
from time import time
import torch
# Training loop
errors = []
free_energies_val = []
free_energies_train = []
start_time = time()

for epoch in range(1, num_epochs+1):
    iteration = 0
    error = 0
    for batch in get_batches(X_train, batch_size, shuffle=True):
        iteration += 1
   
        # Compute gradients and errors
        error += model.compute_grad(batch)
        
        # Update parameters - use momentum as explained in Hinton's guide
        if(epoch > 5):
            model.update(lr, momentum=0.5)
        else:
            model.update(lr, momentum=0.9)
        

        
    print("epoch:{} \t error:{:.4f} \t training time:{:.2f} s".format(epoch, error, time()-start_time))
    errors.append(error)
    
    # == Calcule DKL pour le CRBM à chaque époque ==
    dkl_values = []
    num_samples = 10 # Nbre of samples tu use in the DKL
    
    with torch.no_grad():
        for i in range(num_samples):
            img = X_val[i].reshape(-1)  # Assure-toi que X_val est bien défini
            img_resized = img.reshape(28, 28).flatten()

    
            # Normalisation
            img_rescaled = img_resized / np.max(img_resized) if np.max(img_resized) > 0 else img_resized
            recon = model.get_reconstruction(img_rescaled)
    
            # Empêche division par zéro
            P = recon / np.sum(recon) if np.sum(recon) > 0 else np.ones_like(recon) / len(recon)
            Q = img_rescaled / np.sum(img_rescaled) if np.sum(img_rescaled) > 0 else np.ones_like(img_rescaled) / len(img_rescaled)
    
            dkl = KL(P, Q)
            dkl_values.append(dkl)
    
    mean_dkl = np.mean(dkl_values)
    crbm_dkl_per_epoch.append(mean_dkl)
    print(f"Epoch {epoch} - Mean DKL: {mean_dkl:.4f}")
# Out:
# epoch:1 	 error:38137.4930 	 training time:10.90 s
# Epoch 1 - Mean DKL: 1.4427
# epoch:2 	 error:23962.1405 	 training time:24.72 s
# Epoch 2 - Mean DKL: 1.2257
# epoch:3 	 error:22117.6279 	 training time:35.25 s
# Epoch 3 - Mean DKL: 1.0859
# epoch:4 	 error:21222.9793 	 training time:45.64 s
# Epoch 4 - Mean DKL: 1.0293
# epoch:5 	 error:20667.6262 	 training time:56.07 s
# Epoch 5 - Mean DKL: 0.9692
# epoch:6 	 error:20302.9280 	 training time:67.81 s
# Epoch 6 - Mean DKL: 0.9365
# epoch:7 	 error:20019.9027 	 training time:80.49 s
# Epoch 7 - Mean DKL: 0.9161
# epoch:8 	 error:19778.6540 	 training time:93.73 s
# Epoch 8 - Mean DKL: 0.8848
# epoch:9 	 error:19582.4121 	 training time:106.14 s
# Epoch 9 - Mean DKL: 0.8953
# epoch:10 	 error:19427.9521 	 training time:120.65 s
# Epoch 10 - Mean DKL: 0.8686
# epoch:11 	 error:19277.6335 	 training time:133.05 s
# Epoch 11 - Mean DKL: 0.8895
# epoch:12 	 error:19133.4724 	 training time:145.66 s
# Epoch 12 - Mean DKL: 0.8248
# epoch:13 	 error:19046.5417 	 training time:162.30 s
# Epoch 13 - Mean DKL: 0.8649
# epoch:14 	 error:18899.0354 	 training time:173.71 s
# Epoch 14 - Mean DKL: 0.8802
# epoch:15 	 error:18808.9895 	 training time:183.95 s
# Epoch 15 - Mean DKL: 0.8903
# epoch:16 	 error:18737.0219 	 training time:194.90 s
# Epoch 16 - Mean DKL: 0.8803
# epoch:17 	 error:18652.7707 	 training time:205.81 s
# Epoch 17 - Mean DKL: 0.8421
# epoch:18 	 error:18576.4418 	 training time:216.71 s
# Epoch 18 - Mean DKL: 0.8308
# epoch:19 	 error:18486.3755 	 training time:226.30 s
# Epoch 19 - Mean DKL: 0.8210
# epoch:20 	 error:18426.5385 	 training time:235.51 s
# Epoch 20 - Mean DKL: 0.8121
# epoch:21 	 error:18362.6794 	 training time:244.80 s
# Epoch 21 - Mean DKL: 0.7899
# epoch:22 	 error:18309.7404 	 training time:254.08 s
# Epoch 22 - Mean DKL: 0.7953
# epoch:23 	 error:18275.3528 	 training time:263.31 s
# Epoch 23 - Mean DKL: 0.7933
# epoch:24 	 error:18228.3316 	 training time:272.49 s
# Epoch 24 - Mean DKL: 0.8043
# epoch:25 	 error:18188.3958 	 training time:281.59 s
# Epoch 25 - Mean DKL: 0.7824
# epoch:26 	 error:18150.6964 	 training time:291.23 s
# Epoch 26 - Mean DKL: 0.7920
# epoch:27 	 error:18114.4787 	 training time:301.16 s
# Epoch 27 - Mean DKL: 0.7723
# epoch:28 	 error:18068.2837 	 training time:310.41 s
# Epoch 28 - Mean DKL: 0.7741
# epoch:29 	 error:18035.5040 	 training time:319.90 s
# Epoch 29 - Mean DKL: 0.7751
# epoch:30 	 error:17982.6974 	 training time:329.16 s
# Epoch 30 - Mean DKL: 0.7724
# epoch:31 	 error:17951.9856 	 training time:338.39 s
# Epoch 31 - Mean DKL: 0.7453
# epoch:32 	 error:17898.4100 	 training time:347.50 s
# Epoch 32 - Mean DKL: 0.7284
# epoch:33 	 error:17865.0225 	 training time:357.15 s
# Epoch 33 - Mean DKL: 0.7787
# epoch:34 	 error:17841.6221 	 training time:366.29 s
# Epoch 34 - Mean DKL: 0.7456
# epoch:35 	 error:17798.6942 	 training time:375.82 s
# Epoch 35 - Mean DKL: 0.7255
# epoch:36 	 error:17792.9400 	 training time:390.88 s
# Epoch 36 - Mean DKL: 0.7329
# epoch:37 	 error:17780.3543 	 training time:401.32 s
# Epoch 37 - Mean DKL: 0.7624
# epoch:38 	 error:17726.5140 	 training time:410.61 s
# Epoch 38 - Mean DKL: 0.7526
# epoch:39 	 error:17724.5288 	 training time:420.36 s
# Epoch 39 - Mean DKL: 0.7219
# epoch:40 	 error:17687.9715 	 training time:430.75 s
# Epoch 40 - Mean DKL: 0.7150
# epoch:41 	 error:17652.2413 	 training time:442.70 s
# Epoch 41 - Mean DKL: 0.7343
# epoch:42 	 error:17631.0625 	 training time:454.20 s
# Epoch 42 - Mean DKL: 0.7367
# epoch:43 	 error:17630.6724 	 training time:464.15 s
# Epoch 43 - Mean DKL: 0.7112
# epoch:44 	 error:17596.3732 	 training time:478.19 s
# Epoch 44 - Mean DKL: 0.7270
# epoch:45 	 error:17582.1765 	 training time:489.10 s
# Epoch 45 - Mean DKL: 0.7185
# epoch:46 	 error:17565.2068 	 training time:499.01 s
# Epoch 46 - Mean DKL: 0.7526
# epoch:47 	 error:17537.8921 	 training time:510.30 s
# Epoch 47 - Mean DKL: 0.7258
# epoch:48 	 error:17524.4217 	 training time:521.74 s
# Epoch 48 - Mean DKL: 0.7598
# epoch:49 	 error:17521.1237 	 training time:532.92 s
# Epoch 49 - Mean DKL: 0.6932
# epoch:50 	 error:17519.2945 	 training time:544.35 s
# Epoch 50 - Mean DKL: 0.7092
# epoch:51 	 error:17499.9119 	 training time:557.19 s
# Epoch 51 - Mean DKL: 0.7107
# epoch:52 	 error:17498.5460 	 training time:573.01 s
# Epoch 52 - Mean DKL: 0.6895
# epoch:53 	 error:17521.6543 	 training time:585.62 s
# Epoch 53 - Mean DKL: 0.7074
# epoch:54 	 error:17477.2172 	 training time:598.51 s
# Epoch 54 - Mean DKL: 0.7170
# epoch:55 	 error:17492.5306 	 training time:613.70 s
# Epoch 55 - Mean DKL: 0.7215
# epoch:56 	 error:17475.1323 	 training time:626.51 s
# Epoch 56 - Mean DKL: 0.7090
# epoch:57 	 error:17472.2018 	 training time:636.45 s
# Epoch 57 - Mean DKL: 0.7096
# epoch:58 	 error:17461.9413 	 training time:646.03 s
# Epoch 58 - Mean DKL: 0.7205
# epoch:59 	 error:17484.8954 	 training time:655.89 s
# Epoch 59 - Mean DKL: 0.7398
# epoch:60 	 error:17482.9054 	 training time:665.56 s
# Epoch 60 - Mean DKL: 0.7219
# epoch:61 	 error:17446.9506 	 training time:675.20 s
# Epoch 61 - Mean DKL: 0.7210
# epoch:62 	 error:17456.8366 	 training time:685.44 s
# Epoch 62 - Mean DKL: 0.7073
# epoch:63 	 error:17457.9838 	 training time:696.09 s
# Epoch 63 - Mean DKL: 0.7204
# epoch:64 	 error:17464.3974 	 training time:706.59 s
# Epoch 64 - Mean DKL: 0.6930
# epoch:65 	 error:17466.7862 	 training time:716.32 s
# Epoch 65 - Mean DKL: 0.7261
# epoch:66 	 error:17469.7523 	 training time:726.38 s
# Epoch 66 - Mean DKL: 0.6776
# epoch:67 	 error:17460.7442 	 training time:736.15 s
# Epoch 67 - Mean DKL: 0.6986
# epoch:68 	 error:17457.9021 	 training time:747.72 s
# Epoch 68 - Mean DKL: 0.6882
# epoch:69 	 error:17463.0781 	 training time:758.15 s
# Epoch 69 - Mean DKL: 0.7076
# epoch:70 	 error:17473.0875 	 training time:768.54 s
# Epoch 70 - Mean DKL: 0.6888
# epoch:71 	 error:17469.4254 	 training time:778.85 s
# Epoch 71 - Mean DKL: 0.7048
# epoch:72 	 error:17452.6653 	 training time:789.43 s
# Epoch 72 - Mean DKL: 0.6899
# epoch:73 	 error:17462.5937 	 training time:804.57 s
# Epoch 73 - Mean DKL: 0.6574
# epoch:74 	 error:17455.4904 	 training time:814.21 s
# Epoch 74 - Mean DKL: 0.6737
# epoch:75 	 error:17464.9482 	 training time:824.29 s
# Epoch 75 - Mean DKL: 0.6769
# epoch:76 	 error:17457.2124 	 training time:833.52 s
# Epoch 76 - Mean DKL: 0.6983
# epoch:77 	 error:17428.2393 	 training time:842.99 s
# Epoch 77 - Mean DKL: 0.6817
# epoch:78 	 error:17444.0891 	 training time:857.15 s
# Epoch 78 - Mean DKL: 0.6794
# epoch:79 	 error:17454.5665 	 training time:867.57 s
# Epoch 79 - Mean DKL: 0.6756
# epoch:80 	 error:17442.3690 	 training time:877.79 s
# Epoch 80 - Mean DKL: 0.6521
# epoch:81 	 error:17460.0395 	 training time:887.84 s
# Epoch 81 - Mean DKL: 0.6913
# epoch:82 	 error:17450.5616 	 training time:898.21 s
# Epoch 82 - Mean DKL: 0.6686
# epoch:83 	 error:17459.9701 	 training time:908.45 s
# Epoch 83 - Mean DKL: 0.6780
# epoch:84 	 error:17461.8289 	 training time:919.00 s
# Epoch 84 - Mean DKL: 0.6815
# epoch:85 	 error:17467.1926 	 training time:929.61 s
# Epoch 85 - Mean DKL: 0.6652
# epoch:86 	 error:17426.7835 	 training time:940.17 s
# Epoch 86 - Mean DKL: 0.6866
# epoch:87 	 error:17483.6277 	 training time:950.88 s
# Epoch 87 - Mean DKL: 0.6583
# epoch:88 	 error:17451.3192 	 training time:961.72 s
# Epoch 88 - Mean DKL: 0.6536
# epoch:89 	 error:17450.1564 	 training time:972.65 s
# Epoch 89 - Mean DKL: 0.6790
# epoch:90 	 error:17441.2561 	 training time:983.68 s
# Epoch 90 - Mean DKL: 0.6416
# epoch:91 	 error:17436.0285 	 training time:994.61 s
# Epoch 91 - Mean DKL: 0.6505
# epoch:92 	 error:17468.4986 	 training time:1005.52 s
# Epoch 92 - Mean DKL: 0.6570
# epoch:93 	 error:17434.4378 	 training time:1016.13 s
# Epoch 93 - Mean DKL: 0.6416
# epoch:94 	 error:17445.3002 	 training time:1027.64 s
# Epoch 94 - Mean DKL: 0.6351
# epoch:95 	 error:17437.4380 	 training time:1038.77 s
# Epoch 95 - Mean DKL: 0.6528
# epoch:96 	 error:17460.6904 	 training time:1049.52 s
# Epoch 96 - Mean DKL: 0.6494
# epoch:97 	 error:17458.0673 	 training time:1060.08 s
# Epoch 97 - Mean DKL: 0.6635
# epoch:98 	 error:17450.8687 	 training time:1070.55 s
# Epoch 98 - Mean DKL: 0.6455
# epoch:99 	 error:17461.4029 	 training time:1081.60 s
# Epoch 99 - Mean DKL: 0.6592
# epoch:100 	 error:17466.4809 	 training time:1094.61 s
# Epoch 100 - Mean DKL: 0.6611

# %%
plt.clf()
title="weights"
fig, axes = plt.subplots(10, 10, gridspec_kw = {'wspace':0.1, 'hspace':0.1}, figsize=(8, 8))
fig.suptitle(title)
for i in range(10):
    for j in range(10):
        axes[i, j].imshow(model.W[:,i*10+j].reshape(28, 28), cmap='gray')
        axes[i, j].axis('off')
        
plt.savefig("weights")
plt.show()
plt.close()

# %%
images = selected_imgs
num_samples = len(selected_imgs)
plt.clf()
fig, axes = plt.subplots(2, num_samples, gridspec_kw = {'wspace':0, 'hspace':0.1}, figsize=(2*num_samples, 4))
fig.suptitle("images")
text = axes[0, 0].text(-7, 14,"original", size=15,
                       verticalalignment='center', rotation=-270)
text = axes[1, 0].text(-7, 13,"reconstructed", size=15,
                       verticalalignment='center', rotation=-270)
for n in range(num_samples):
    axes[0, n].imshow(images[n].reshape(28, 28), cmap='gray')
    axes[1, n].imshow(model.get_reconstruction(images[n].reshape(28*28)).reshape(28, 28), cmap='gray')
    axes[0, n].axis('off')
    axes[1, n].axis('off')
plt.savefig("reconstructed")
plt.show()
plt.close()

# %% [markdown]
# ## VAE

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torchvision.utils import save_image
import cv2
import matplotlib.pyplot as plt
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %% [markdown]
# #### Downloading the dataset

# %%
trainset = torchvision.datasets.MNIST(root='./data', train = True, download = True, transform = transforms.ToTensor())
testset = torchvision.datasets.MNIST(root='./data', train = False, download = True, transform = transforms.ToTensor())
xtrain = trainset.data.numpy()
ytrain = trainset.targets.numpy()
x_val_pre = testset.data[:1000].numpy()
y_val = testset.targets[:1000].numpy()

# %% [markdown]
# ### Creating x_train and y_train with 1000 images from each class and binarizing the pixels

# %%
count = np.zeros(10)
idx = []
for i in range(0, len(ytrain)):
  for j in range(10):
    if(ytrain[i] == j):
      count[j] += 1
      if(count[j]<=1000):
        idx = np.append(idx, i)
        
y_train = ytrain[idx.astype('int')]
x_train_pre = xtrain[idx.astype('int')]

# %% [markdown]
# ### Resizing the images from 28x28 to 14x14

# %%
r,_,_ = x_train_pre.shape
x_train = np.zeros([r,14,14])
for i in range(r):
  a = cv2.resize(x_train_pre[i].astype('float32'), (14,14)) # Resizing the image from 28*28 to 14*14
  x_train[i] = a

r,_,_ = x_val_pre.shape
x_val = np.zeros([r,14,14])
for i in range(r):
  a = cv2.resize(x_val_pre[i].astype('float32'), (14,14)) # Resizing the image from 28*28 to 14*14
  x_val[i] = a

# %% [markdown]
# ### Binarizing

# %%
x_train = np.where(x_train > 128, 1, 0)
x_val = np.where(x_val > 128, 1, 0)
x_train = x_train.astype(np.float32)
x_val = x_val.astype(np.float32)

# %% [markdown]
# ### Creating dataloaders

# %%
batch_size = 32
trainloader = torch.utils.data.DataLoader([[x_train[i], y_train[i]] for i in range(len(y_train))], shuffle=True, batch_size=batch_size)
testloader = torch.utils.data.DataLoader([[x_val[i], y_val[i]] for i in range(len(y_val))], shuffle=True, batch_size=100)

# %% [markdown]
# ### Variational Auto Encoder model

# %%
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()

        self.fc1 = nn.Linear(196, 128) #Encoder
        self.fc21 = nn.Linear(128, 8) #mu
        self.fc22 = nn.Linear(128, 8) #sigma

        self.fc3 = nn.Linear(8, 128) #Decoder
        self.fc4 = nn.Linear(128, 196)
        
    def encoder(self, x):
        h = torch.tanh(self.fc1(x))
        return self.fc21(h), self.fc22(h) # mu, std
    
    def sampling(self, mu, std): # Reparameterization trick
        eps1 = torch.randn_like(std)
        eps2 = torch.randn_like(std)
        return 0.5*((eps1 * std + mu) + (eps2 * std + mu)) # Using two samples to compute expectation over z

    def decoder(self, z):
        h = torch.tanh(self.fc3(z))
        return torch.sigmoid(self.fc4(h)) 
    
    def forward(self, x):
        mu, std = self.encoder(x.view(-1, 196))
        z = self.sampling(mu, std)
        return self.decoder(z), mu, std
vae_model = VAE()
if torch.cuda.is_available():
    vae_model.cuda()

# %% [markdown]
# ### Defining loss, optimizer and LR scheduler

# %%
optimizer = torch.optim.Adam(vae_model.parameters(), lr = 0.002)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', factor=0.5, 
                             patience=5, threshold=0.001, cooldown=0,
                             min_lr=0.0001)

def loss_function(y, x, mu, std): 
    ERR = F.binary_cross_entropy(y, x.view(-1, 196), reduction='sum')
    KLD = -0.5 * torch.sum(1 + torch.log(std**2) - mu**2 - std**2)
    return ERR + KLD, -ERR, -KLD

# %% [markdown]
# ### Training and Validating

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
vae_model.to(device)
count=0
err_l, kld_l, n_wu, testl, update = [], [], [], [], []
for epoch in range(1, 100):
    
    train_loss = 0
    for batch_idx, (data, _) in enumerate(trainloader):
        vae_model.train()
        data = data.to(device)
        bsize = data.shape[0]
        recon_batch, mu, std = vae_model(data)
        loss, err, kld = loss_function(recon_batch, data, mu, std)
        loss.backward()
        train_loss += err.item() + kld.item()
        optimizer.step()
        optimizer.zero_grad()
        err_l.append(err.item()/bsize)
        kld_l.append(kld.item()/bsize)
        count+=1
        n_wu.append(count)

        if (count%100 == 0): # Validating every 100 weight updates
          vae_model.eval()
          a, _ = next(iter(testloader))
          a = a.to(device)
          trecon, tmu, tstd = vae_model(a)
          tloss, terr, tkld = loss_function(trecon, a, tmu, tstd)
          testl.append(terr/100)
          update.append(count)

    scheduler.step(train_loss / len(trainloader.dataset))
    
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(trainloader.dataset)))
    vae_model.eval()
    test_loss= 0
    with torch.no_grad():
        for data, _ in testloader:
            data = data.to(device)
            recon, mu, std =vae_model(data)
            loss, err, kld = loss_function(recon, data, mu, std)
            test_loss += err + kld
    
    test_loss /= len(testloader.dataset)
    print('====> Test set loss: {:.4f}'.format(test_loss))
# Out:
# ====> Epoch: 1 Average loss: -52.2766
# ====> Test set loss: -41.8722
# ====> Epoch: 2 Average loss: -39.9399
# ====> Test set loss: -38.1934
# ====> Epoch: 3 Average loss: -37.4952
# ====> Test set loss: -36.8069
# ====> Epoch: 4 Average loss: -36.4924
# ====> Test set loss: -36.0444
# ====> Epoch: 5 Average loss: -35.7916
# ====> Test set loss: -35.5609
# ====> Epoch: 6 Average loss: -35.2579
# ====> Test set loss: -35.3097
# ====> Epoch: 7 Average loss: -34.8183
# ====> Test set loss: -34.8269
# ====> Epoch: 8 Average loss: -34.3836
# ====> Test set loss: -34.4325
# ====> Epoch: 9 Average loss: -34.1396
# ====> Test set loss: -34.3162
# ====> Epoch: 10 Average loss: -33.8469
# ====> Test set loss: -33.8821
# ====> Epoch: 11 Average loss: -33.6772
# ====> Test set loss: -33.9158
# ====> Epoch: 12 Average loss: -33.4137
# ====> Test set loss: -33.7415
# ====> Epoch: 13 Average loss: -33.2726
# ====> Test set loss: -33.6413
# ====> Epoch: 14 Average loss: -33.0734
# ====> Test set loss: -33.5132
# ====> Epoch: 15 Average loss: -32.9350
# ====> Test set loss: -33.0765
# ====> Epoch: 16 Average loss: -32.7813
# ====> Test set loss: -33.1659
# ====> Epoch: 17 Average loss: -32.6494
# ====> Test set loss: -33.1512
# ====> Epoch: 18 Average loss: -32.5939
# ====> Test set loss: -33.1090
# ====> Epoch: 19 Average loss: -32.4948
# ====> Test set loss: -32.8152
# ====> Epoch: 20 Average loss: -32.3053
# ====> Test set loss: -32.7933
# ====> Epoch: 21 Average loss: -32.3063
# ====> Test set loss: -32.9697
# ====> Epoch: 22 Average loss: -32.2271
# ====> Test set loss: -32.5608
# ====> Epoch: 23 Average loss: -32.1634
# ====> Test set loss: -32.6629
# ====> Epoch: 24 Average loss: -32.0004
# ====> Test set loss: -32.6176
# ====> Epoch: 25 Average loss: -31.9466
# ====> Test set loss: -32.4105
# ====> Epoch: 26 Average loss: -31.9241
# ====> Test set loss: -32.3849
# ====> Epoch: 27 Average loss: -31.8597
# ====> Test set loss: -32.2566
# ====> Epoch: 28 Average loss: -31.7922
# ====> Test set loss: -32.3783
# ====> Epoch: 29 Average loss: -31.7372
# ====> Test set loss: -32.3875
# ====> Epoch: 30 Average loss: -31.6410
# ====> Test set loss: -32.1610
# ====> Epoch: 31 Average loss: -31.6404
# ====> Test set loss: -32.3503
# ====> Epoch: 32 Average loss: -31.5502
# ====> Test set loss: -32.1328
# ====> Epoch: 33 Average loss: -31.5061
# ====> Test set loss: -32.1454
# ====> Epoch: 34 Average loss: -31.5240
# ====> Test set loss: -32.2609
# ====> Epoch: 35 Average loss: -31.4888
# ====> Test set loss: -31.9963
# ====> Epoch: 36 Average loss: -31.3686
# ====> Test set loss: -32.2334
# ====> Epoch: 37 Average loss: -31.3329
# ====> Test set loss: -32.3291
# ====> Epoch: 38 Average loss: -31.3797
# ====> Test set loss: -32.2153
# ====> Epoch: 39 Average loss: -31.2715
# ====> Test set loss: -31.9141
# ====> Epoch: 40 Average loss: -31.2734
# ====> Test set loss: -32.2271
# ====> Epoch: 41 Average loss: -31.3090
# ====> Test set loss: -32.2664
# ====> Epoch: 42 Average loss: -31.1934
# ====> Test set loss: -32.2381
# ====> Epoch: 43 Average loss: -31.1686
# ====> Test set loss: -31.9914
# ====> Epoch: 44 Average loss: -31.0608
# ====> Test set loss: -32.0462
# ====> Epoch: 45 Average loss: -31.1413
# ====> Test set loss: -31.9205
# ====> Epoch: 46 Average loss: -31.1357
# ====> Test set loss: -31.7698
# ====> Epoch: 47 Average loss: -31.0446
# ====> Test set loss: -32.1411
# ====> Epoch: 48 Average loss: -31.0548
# ====> Test set loss: -31.9718
# ====> Epoch: 49 Average loss: -30.9995
# ====> Test set loss: -31.8952
# ====> Epoch: 50 Average loss: -30.9805
# ====> Test set loss: -31.9402
# ====> Epoch: 51 Average loss: -30.9769
# ====> Test set loss: -31.6653
# ====> Epoch: 52 Average loss: -30.9255
# ====> Test set loss: -31.5859
# ====> Epoch: 53 Average loss: -30.8957
# ====> Test set loss: -31.6079
# ====> Epoch: 54 Average loss: -30.9097
# ====> Test set loss: -31.8346
# ====> Epoch: 55 Average loss: -30.9511
# ====> Test set loss: -31.6219
# ====> Epoch: 56 Average loss: -30.8375
# ====> Test set loss: -31.7280
# ====> Epoch: 57 Average loss: -30.8117
# ====> Test set loss: -31.5724
# ====> Epoch: 58 Average loss: -30.8179
# ====> Test set loss: -31.6373
# ====> Epoch: 59 Average loss: -30.8507
# ====> Test set loss: -31.6581
# ====> Epoch: 60 Average loss: -30.7167
# ====> Test set loss: -31.7022
# ====> Epoch: 61 Average loss: -30.7784
# ====> Test set loss: -31.5462
# ====> Epoch: 62 Average loss: -30.7411
# ====> Test set loss: -31.7711
# ====> Epoch: 63 Average loss: -30.7061
# ====> Test set loss: -31.5521
# ====> Epoch: 64 Average loss: -30.7467
# ====> Test set loss: -31.7408
# ====> Epoch: 65 Average loss: -30.7126
# ====> Test set loss: -31.8284
# ====> Epoch: 66 Average loss: -30.6780
# ====> Test set loss: -31.7452
# ====> Epoch: 67 Average loss: -30.7033
# ====> Test set loss: -31.6925
# ====> Epoch: 68 Average loss: -30.6125
# ====> Test set loss: -31.8119
# ====> Epoch: 69 Average loss: -30.6997
# ====> Test set loss: -31.4762
# ====> Epoch: 70 Average loss: -30.5720
# ====> Test set loss: -31.6830
# ====> Epoch: 71 Average loss: -30.6215
# ====> Test set loss: -31.6502
# ====> Epoch: 72 Average loss: -30.6076
# ====> Test set loss: -31.5462
# ====> Epoch: 73 Average loss: -30.5415
# ====> Test set loss: -31.7967
# ====> Epoch: 74 Average loss: -30.5780
# ====> Test set loss: -31.5720
# ====> Epoch: 75 Average loss: -30.5304
# ====> Test set loss: -31.6023
# ====> Epoch: 76 Average loss: -30.5153
# ====> Test set loss: -31.7741
# ====> Epoch: 77 Average loss: -30.5492
# ====> Test set loss: -31.5068
# ====> Epoch: 78 Average loss: -30.5115
# ====> Test set loss: -31.4701
# ====> Epoch: 79 Average loss: -30.4763
# ====> Test set loss: -31.6275
# ====> Epoch: 80 Average loss: -30.4304
# ====> Test set loss: -31.6326
# ====> Epoch: 81 Average loss: -30.4422
# ====> Test set loss: -31.6206
# ====> Epoch: 82 Average loss: -30.4799
# ====> Test set loss: -31.6310
# ====> Epoch: 83 Average loss: -30.4635
# ====> Test set loss: -31.4920
# ====> Epoch: 84 Average loss: -30.4871
# ====> Test set loss: -31.5711
# ====> Epoch: 85 Average loss: -30.4699
# ====> Test set loss: -31.6379
# ====> Epoch: 86 Average loss: -30.4227
# ====> Test set loss: -31.6045
# ====> Epoch: 87 Average loss: -30.4574
# ====> Test set loss: -31.3074
# ====> Epoch: 88 Average loss: -30.3656
# ====> Test set loss: -31.5313
# ====> Epoch: 89 Average loss: -30.4168
# ====> Test set loss: -31.6780
# ====> Epoch: 90 Average loss: -30.4415
# ====> Test set loss: -31.3861
# ====> Epoch: 91 Average loss: -30.3130
# ====> Test set loss: -31.5415
# ====> Epoch: 92 Average loss: -30.3473
# ====> Test set loss: -31.4542
# ====> Epoch: 93 Average loss: -30.3260
# ====> Test set loss: -31.4628
# ====> Epoch: 94 Average loss: -30.3059
# ====> Test set loss: -31.6739
# ====> Epoch: 95 Average loss: -30.3283
# ====> Test set loss: -31.4158
# ====> Epoch: 96 Average loss: -30.3234
# ====> Test set loss: -31.3872
# ====> Epoch: 97 Average loss: -30.3230
# ====> Test set loss: -31.6215
# ====> Epoch: 98 Average loss: -30.3671
# ====> Test set loss: -31.4262
# ====> Epoch: 99 Average loss: -30.3339
# ====> Test set loss: -31.5803

# %%
(kld_l[::60])
# Out:
# [-17.298967361450195,
#  -2.377103567123413,
#  -2.608246326446533,
#  -3.1305794715881348,
#  -3.7604498863220215,
#  -4.14865255355835,
#  -4.59820032119751,
#  -4.854983329772949,
#  -4.6170172691345215,
#  -4.992763042449951,
#  -4.735485553741455,
#  -5.2684736251831055,
#  -5.032470226287842,
#  -5.457083702087402,
#  -5.6599016189575195,
#  -5.2107672691345215,
#  -5.481722831726074,
#  -5.8702216148376465,
#  -5.247443675994873,
#  -5.617749214172363,
#  -6.743961334228516,
#  -5.714948654174805,
#  -5.981090068817139,
#  -5.993541717529297,
#  -5.541040420532227,
#  -6.2667412757873535,
#  -6.025907516479492,
#  -6.082305908203125,
#  -5.883393287658691,
#  -6.035434246063232,
#  -6.007424354553223,
#  -6.0426530838012695,
#  -6.352788925170898,
#  -5.988531112670898,
#  -5.9438652992248535,
#  -6.115437984466553,
#  -6.116868495941162,
#  -5.5280890464782715,
#  -6.019022464752197,
#  -6.924169063568115,
#  -6.370879173278809,
#  -6.19670295715332,
#  -6.9538044929504395,
#  -5.973567008972168,
#  -6.235809326171875,
#  -6.341316223144531,
#  -6.406370162963867,
#  -6.439852237701416,
#  -6.581528663635254,
#  -5.980210304260254,
#  -6.196587562561035,
#  -6.687785625457764,
#  -6.327870845794678,
#  -5.96867036819458,
#  -6.191478729248047,
#  -6.261198043823242,
#  -6.726334571838379,
#  -6.435856819152832,
#  -6.530908584594727,
#  -6.945810317993164,
#  -5.93146276473999,
#  -6.021153926849365,
#  -5.766158580780029,
#  -6.731701850891113,
#  -6.6490607261657715,
#  -6.721941947937012,
#  -6.576235771179199,
#  -6.730932712554932,
#  -6.329751968383789,
#  -6.286806583404541,
#  -6.474106788635254,
#  -6.574541091918945,
#  -7.215795516967773,
#  -6.659038066864014,
#  -6.888725280761719,
#  -6.668473720550537,
#  -7.027702331542969,
#  -6.572812557220459,
#  -6.640663146972656,
#  -6.2294511795043945,
#  -6.733362197875977,
#  -6.503084659576416,
#  -6.688896179199219,
#  -7.462687015533447,
#  -7.013030052185059,
#  -6.479633331298828,
#  -6.79255485534668,
#  -6.525197505950928,
#  -6.635213375091553,
#  -6.8433732986450195,
#  -6.869816780090332,
#  -7.419678211212158,
#  -6.066113471984863,
#  -6.860480308532715,
#  -6.416743755340576,
#  -6.951113224029541,
#  -7.039079666137695,
#  -6.543025016784668,
#  -6.9666571617126465,
#  -6.6769256591796875,
#  -6.840126037597656,
#  -6.707892894744873,
#  -6.446045875549316,
#  -6.835801601409912,
#  -6.6499552726745605,
#  -7.404289245605469,
#  -6.307000160217285,
#  -7.360368728637695,
#  -7.183107852935791,
#  -6.475992202758789,
#  -7.142195701599121,
#  -7.085804462432861,
#  -6.349386215209961,
#  -6.642612934112549,
#  -6.583446502685547,
#  -7.520895957946777,
#  -7.578994274139404,
#  -6.8753509521484375,
#  -7.1616668701171875,
#  -6.983450412750244,
#  -6.692955017089844,
#  -7.356797695159912,
#  -7.251877784729004,
#  -6.782671928405762,
#  -6.7752532958984375,
#  -6.637008190155029,
#  -6.926209449768066,
#  -6.857494354248047,
#  -7.017401695251465,
#  -7.24660062789917,
#  -7.477062225341797,
#  -7.186553955078125,
#  -7.299454689025879,
#  -7.136727333068848,
#  -7.5697126388549805,
#  -7.166315078735352,
#  -7.168612480163574,
#  -7.053974151611328,
#  -7.166976451873779,
#  -6.077570915222168,
#  -6.965962886810303,
#  -7.26385498046875,
#  -6.718751430511475,
#  -6.9614057540893555,
#  -7.485877990722656,
#  -7.288531303405762,
#  -6.645347595214844,
#  -7.569606304168701,
#  -7.157989025115967,
#  -7.553644180297852,
#  -7.00185489654541,
#  -7.373230457305908,
#  -6.7712178230285645,
#  -7.478960037231445,
#  -6.924234867095947,
#  -7.54298734664917,
#  -7.140506744384766,
#  -7.156791687011719,
#  -7.23891544342041,
#  -7.080122470855713,
#  -6.836334705352783,
#  -7.61298131942749,
#  -7.06223726272583,
#  -7.5883331298828125,
#  -7.218969821929932,
#  -7.484699726104736,
#  -7.278242111206055,
#  -7.474783420562744,
#  -7.831701755523682,
#  -7.1848859786987305,
#  -7.064708709716797,
#  -7.752557754516602,
#  -7.049057960510254,
#  -6.870857238769531,
#  -7.306070327758789,
#  -7.112714767456055,
#  -7.444855213165283,
#  -7.224623680114746,
#  -6.612127780914307,
#  -7.277134895324707,
#  -7.675899505615234,
#  -7.0044426918029785,
#  -7.583229064941406,
#  -7.09780216217041,
#  -7.363385200500488,
#  -7.627146244049072,
#  -7.142160415649414,
#  -7.6095733642578125,
#  -7.454991817474365,
#  -7.531243801116943,
#  -7.3162617683410645,
#  -7.558263778686523,
#  -7.852829456329346,
#  -8.496603012084961,
#  -7.075529098510742,
#  -7.766439914703369,
#  -7.827617645263672,
#  -7.604517936706543,
#  -7.878878116607666,
#  -7.000689506530762,
#  -7.260617733001709,
#  -7.625299453735352,
#  -6.765773773193359,
#  -7.262612342834473,
#  -7.808099269866943,
#  -7.349099159240723,
#  -7.042103290557861,
#  -7.735570430755615,
#  -7.486286163330078,
#  -7.310755729675293,
#  -7.37612771987915,
#  -7.5984015464782715,
#  -7.716052055358887,
#  -7.689834117889404,
#  -6.903539657592773,
#  -7.534477233886719,
#  -7.611476898193359,
#  -7.338592529296875,
#  -7.474171161651611,
#  -7.747316360473633,
#  -7.178483963012695,
#  -7.4018354415893555,
#  -7.749139308929443,
#  -6.906839847564697,
#  -7.973465442657471,
#  -8.269314765930176,
#  -7.468451499938965,
#  -7.559609889984131,
#  -7.293999671936035,
#  -7.760493278503418,
#  -7.507816314697266,
#  -7.707257270812988,
#  -7.1805548667907715,
#  -7.691714763641357,
#  -7.51523494720459,
#  -7.456111907958984,
#  -7.511013031005859,
#  -7.668278694152832,
#  -6.93704891204834,
#  -7.255699634552002,
#  -7.3528900146484375,
#  -7.580222129821777,
#  -6.7240447998046875,
#  -7.488895893096924,
#  -7.751428604125977,
#  -7.4716033935546875,
#  -7.134992599487305,
#  -6.862066268920898,
#  -7.888437271118164,
#  -7.451462268829346,
#  -7.436809539794922,
#  -6.915681838989258,
#  -7.621781826019287,
#  -7.408099174499512,
#  -7.687073230743408,
#  -7.367700576782227,
#  -7.575132846832275,
#  -7.505678176879883,
#  -7.317078590393066,
#  -7.20803165435791,
#  -7.720391750335693,
#  -7.332243919372559,
#  -7.913962364196777,
#  -7.365281105041504,
#  -7.808917045593262,
#  -6.992467403411865,
#  -7.509722709655762,
#  -7.943983554840088,
#  -8.141539573669434,
#  -7.209897994995117,
#  -7.481942653656006,
#  -7.71049690246582,
#  -7.344357490539551,
#  -7.166662216186523,
#  -7.281260013580322,
#  -7.009352684020996,
#  -7.927886486053467,
#  -7.539906024932861,
#  -7.463688850402832,
#  -7.910454273223877,
#  -7.285599231719971,
#  -7.29626989364624,
#  -7.765192031860352,
#  -7.152907848358154,
#  -7.6248393058776855,
#  -7.149537563323975,
#  -8.094854354858398,
#  -7.7257914543151855,
#  -7.7279205322265625,
#  -7.583707332611084,
#  -7.348488807678223,
#  -7.751317977905273,
#  -7.896468162536621,
#  -7.536273002624512,
#  -7.792304039001465,
#  -6.956055641174316,
#  -7.138009071350098,
#  -7.212281227111816,
#  -8.3978271484375,
#  -7.563350677490234,
#  -7.897315979003906,
#  -7.673110008239746,
#  -6.997099876403809,
#  -7.949071884155273,
#  -7.7160139083862305,
#  -7.966554164886475,
#  -7.9225754737854,
#  -7.596100330352783,
#  -7.760036468505859,
#  -7.625688552856445,
#  -7.7044572830200195,
#  -7.342828273773193,
#  -7.012753963470459,
#  -7.984903812408447,
#  -7.15046501159668,
#  -7.737110137939453,
#  -7.460850715637207,
#  -8.064825057983398,
#  -7.220686435699463,
#  -7.890408515930176,
#  -7.787683010101318,
#  -6.9560770988464355,
#  -7.554264068603516,
#  -7.456833839416504,
#  -8.183916091918945,
#  -8.127952575683594,
#  -7.729225158691406,
#  -7.497399806976318,
#  -7.839685916900635,
#  -7.556604862213135,
#  -8.164591789245605,
#  -7.899271011352539,
#  -7.381002426147461,
#  -7.373791694641113,
#  -8.022462844848633,
#  -7.36600923538208,
#  -7.732276916503906,
#  -7.035151958465576,
#  -7.611622333526611,
#  -7.764129161834717,
#  -7.335808753967285,
#  -7.356210708618164,
#  -8.123688697814941,
#  -8.605368614196777,
#  -7.206515789031982,
#  -8.029236793518066,
#  -7.928223133087158,
#  -7.61770486831665,
#  -7.312376499176025,
#  -7.873422622680664,
#  -6.965627670288086,
#  -7.338542938232422,
#  -7.773332118988037,
#  -7.9608964920043945,
#  -7.334553241729736,
#  -7.776063919067383,
#  -7.6971845626831055,
#  -7.891280174255371,
#  -8.012655258178711,
#  -7.677643775939941,
#  -7.372631549835205,
#  -7.892040252685547,
#  -7.942192077636719,
#  -7.395721912384033,
#  -7.690173149108887,
#  -7.480341911315918,
#  -8.23946762084961,
#  -7.60493278503418,
#  -7.891307353973389,
#  -7.363840103149414,
#  -8.266048431396484,
#  -7.344257354736328,
#  -7.671743392944336,
#  -7.670271396636963,
#  -7.777271270751953,
#  -7.819626331329346,
#  -6.735631942749023,
#  -7.589090347290039,
#  -7.164693355560303,
#  -7.804586410522461,
#  -7.867028713226318,
#  -7.987511157989502,
#  -7.344165802001953,
#  -7.995563983917236,
#  -7.377939701080322,
#  -8.335182189941406,
#  -7.84649658203125,
#  -7.124540328979492,
#  -8.088825225830078,
#  -7.972972869873047,
#  -7.545473575592041,
#  -7.672154426574707,
#  -7.109749794006348,
#  -8.121174812316895,
#  -7.079680442810059,
#  -8.19469928741455,
#  -7.556881904602051,
#  -7.666496276855469,
#  -7.936081886291504,
#  -8.362383842468262,
#  -7.963475227355957,
#  -7.598402976989746,
#  -8.346908569335938,
#  -7.421063423156738,
#  -8.124862670898438,
#  -7.203263282775879,
#  -8.2203950881958,
#  -7.659769535064697,
#  -7.731202125549316,
#  -7.5660600662231445,
#  -7.480856895446777,
#  -8.038459777832031,
#  -7.703887462615967,
#  -8.189875602722168,
#  -7.443408966064453,
#  -7.959713935852051,
#  -7.138232231140137,
#  -8.020011901855469,
#  -7.646155834197998,
#  -7.403825759887695,
#  -7.795820236206055,
#  -6.670248508453369,
#  -7.318553924560547,
#  -8.287674903869629,
#  -7.658518314361572,
#  -7.821035385131836,
#  -7.949728012084961,
#  -7.95233154296875,
#  -7.8178253173828125,
#  -7.281246185302734,
#  -7.5616607666015625,
#  -7.630608558654785,
#  -7.378833770751953,
#  -6.848896026611328,
#  -7.475234508514404,
#  -7.882883548736572,
#  -7.746952533721924,
#  -8.154788970947266,
#  -7.3221659660339355,
#  -7.576846122741699,
#  -7.466710090637207,
#  -7.618478775024414,
#  -7.1601080894470215,
#  -7.822751522064209,
#  -7.74119758605957,
#  -7.815928936004639,
#  -8.120299339294434,
#  -7.561090469360352,
#  -7.731951713562012,
#  -7.7397918701171875,
#  -8.03625774383545,
#  -7.754842758178711,
#  -7.49505090713501,
#  -7.946227550506592,
#  -7.795506477355957,
#  -8.219961166381836,
#  -7.70727014541626,
#  -7.469119071960449,
#  -7.96920919418335,
#  -7.584102630615234,
#  -7.874671936035156,
#  -7.871421813964844,
#  -7.648397922515869,
#  -7.664264678955078,
#  -8.046760559082031,
#  -7.496415138244629,
#  -7.758620738983154,
#  -7.85797643661499,
#  -7.65608024597168,
#  -7.216159343719482,
#  -8.363839149475098,
#  -7.1565375328063965,
#  -8.021992683410645,
#  -7.597384452819824,
#  -7.5597028732299805,
#  -7.4370856285095215,
#  -7.595005512237549,
#  -7.544907569885254,
#  -7.462516784667969,
#  -7.27756404876709,
#  -7.416833877563477,
#  -8.292003631591797,
#  -7.5559186935424805,
#  -7.809775352478027,
#  -7.9065375328063965,
#  -8.1302490234375,
#  -8.122903823852539,
#  -7.4428253173828125,
#  -7.423172950744629,
#  -7.287836074829102,
#  -7.082487106323242,
#  -7.994678974151611,
#  -7.361108779907227,
#  -8.33777904510498,
#  -7.507045745849609,
#  -8.022686958312988,
#  -8.258401870727539,
#  -8.025050163269043,
#  -7.500895023345947,
#  -8.08923625946045,
#  -8.100586891174316,
#  -7.714274883270264,
#  -7.9167280197143555,
#  -8.280351638793945,
#  -7.504512786865234,
#  -7.357798099517822,
#  -7.35655403137207,
#  -8.392885208129883,
#  -7.686196327209473,
#  -7.585176944732666,
#  -7.173142910003662,
#  -7.764224052429199,
#  -7.453813552856445,
#  -8.295896530151367,
#  -7.909080982208252,
#  -7.8966217041015625,
#  -7.857544898986816]

# %% [markdown]
# ### Plotting the first and second term of ELBO as a function of weight updates

# %%
plt.figure(figsize=(5,3), dpi=100)
plt.plot(n_wu, err_l, 'b', label='Reconstruction error')
plt.plot(n_wu, kld_l, 'g', label='KL Divergence')
plt.title('Plotting first and second term of ELBO')
plt.xlabel('Number of weight updates')
plt.ylabel('Value')
plt.legend()

# %% [markdown]
# ### Comparing the reconstruction log likelihood term in ELBO on Training vs Validation set

# %%
plt.figure(figsize=(5,3), dpi=100)
plt.plot(err_l, 'g', label='Training Reconstruction log likelihood')
plt.plot(update, [float(v) for v in testl], 'r', label='Validation Reconstruction log likelihood')
plt.title('Reconstruction log likelihood of ELBO: Training vs Validation')
plt.xlabel('Number of weight updates')
plt.ylabel('Value')
plt.legend()

# %%
crbm_epochs = list(range(1, 101))  # 100 epochs
#crbm_errors = np.random.normal(100, 20, 100)  # Placeholder: reconstruction error
crbm_errors = errors
crbm_free_energies_train = np.random.normal(50, 10, 100)  # Placeholder: training free energy
crbm_free_energies_val = np.random.normal(55, 10, 100)    # Placeholder: validation free energy

# %%
vae_epochs = list(range(1, 100))
err_l_vae = err_l
testl_vae = testl
kld_l_vae = kld_l
n_wu_vae = n_wu
update_vae = update

# %%
# Align VAE metrics by averaging per epoch
batches_per_epoch = len(n_wu_vae) // len(vae_epochs)  # Approx. batches per epoch
err_l_vae_per_epoch = []
kld_l_vae_per_epoch = []
for i in range(len(vae_epochs)):
    start_idx = i * batches_per_epoch
    end_idx = (i + 1) * batches_per_epoch
    err_l_vae_per_epoch.append(np.mean(err_l_vae[start_idx:end_idx]))
    kld_l_vae_per_epoch.append(np.mean(kld_l_vae[start_idx:end_idx]))

# %%
# Validation reconstruction log likelihood (align to epochs)
testl_vae_per_epoch = []
updates_per_epoch = len(update_vae) // len(vae_epochs)
for i in range(len(vae_epochs)):
    start_idx = i * updates_per_epoch
    end_idx = (i + 1) * updates_per_epoch
    testl_vae_per_epoch.append(np.mean([float(v) for v in testl_vae[start_idx:end_idx]]))

# %%
# Plot 1: Reconstruction Error Comparison
plt.figure(figsize=(8, 5), dpi=100)
plt.plot(crbm_epochs[:len(vae_epochs)], crbm_errors[:len(vae_epochs)], 'b-', label='CRBM Training Reconstruction Error')
'''plt.plot(vae_epochs, err_l_vae_per_epoch, 'g-', label='VAE Training Reconstruction Log Likelihood')
plt.plot(vae_epochs, testl_vae_per_epoch, 'r-', label='VAE Validation Reconstruction Log Likelihood')'''

plt.plot(vae_epochs, err_l_vae_per_epoch[:len(vae_epochs)], 'g-', label='VAE Training Reconstruction Log Likelihood')
plt.plot(vae_epochs, testl_vae_per_epoch[:len(vae_epochs)], 'r-', label='VAE Validation Reconstruction Log Likelihood')

plt.title('Reconstruction Performance: CRBM vs VAE')
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Metric')
plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# Plot 2: KL Divergence vs Free Energy Comparison
plt.figure(figsize=(8, 5), dpi=100)
plt.plot(crbm_epochs[:len(vae_epochs)], crbm_free_energies_train[:len(vae_epochs)], 'b-', label='CRBM Training Free Energy')
plt.plot(crbm_epochs[:len(vae_epochs)], crbm_free_energies_val[:len(vae_epochs)], 'm-', label='CRBM Validation Free Energy')
plt.plot(vae_epochs, kld_l_vae_per_epoch, 'g-', label='VAE KL Divergence')
plt.title('Divergence/Energy Comparison: CRBM vs VAE')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt
import scienceplots

# %%
with plt.style.context(['science','ieee']):
    fig, ax = plt.subplots(figsize=(7, 5))
    plt.plot(np.linspace(0,100,len(kld_l[::60])), - np.array(kld_l[::60]), 'g-', label='VAE KL Divergence')
    plt.plot(range(len(crbm_dkl_per_epoch)), (crbm_dkl_per_epoch), 'b-', label='CRBM KL Divergence')
    plt.title('CRBM vs VAE')
    plt.xlabel('Iteration')
    plt.ylabel('$D_KL(P_v^{data}||P_v)$')
    plt.yscale('log')
    plt.legend()
    ax.grid(which='major', linestyle='--', linewidth=0.5)
    #plt.savefig('DKLComparison_VAE_vs_CRBM.pdf', format='pdf', bbox_inches='tight')
    plt.savefig('DKLComparison_VAE_vs_CRBM.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
import cv2
from matplotlib.colors import LinearSegmentedColormap
import scienceplots

# %%
fig, axes = plt.subplots(3, num_samples, figsize=(2 * num_samples, 6), gridspec_kw={'wspace': 0, 'hspace': 0.1})
#fig.suptitle("CRBM Reconstruction vs VAE Reconstruction", fontsize=16)

# Add row labels
axes[0, 0].text(-5, 14, "Original", size=14, va='center', rotation=-270)
axes[1, 0].text(-5, 14, "CRBM", size=14, va='center', rotation=-270)
axes[2, 0].text(-5, 14, "VAE", size=14, va='center', rotation=-270)

vae_model.eval()

for n in range(num_samples):
    original = selected_imgs[n]

    # --- ORIGINAL ---
    axes[0, n].imshow(original.reshape(28, 28), cmap='gray')
    axes[0, n].axis('off')

    # --- CRBM RECONSTRUCTION ---
    crbm_input = original.reshape(28 * 28)
    crbm_recon = model.get_reconstruction(crbm_input).reshape(28, 28)
    axes[1, n].imshow(crbm_recon, cmap='gray')
    axes[1, n].axis('off')

    # --- VAE RECONSTRUCTION ---
    # Step 1: Resize original image to 14x14 for VAE input
    input_14 = cv2.resize(original.astype(np.float32), (14, 14), interpolation=cv2.INTER_AREA)

    # Step 2: Convert to tensor and feed into VAE
    input_tensor = torch.tensor(input_14, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)  # shape: [1, 1, 14, 14]
    input_flat = input_tensor.view(1, -1)  # shape: [1, 196]

    with torch.no_grad():
        recon, _, _ = vae_model(input_flat)  # recon is shape: [1, 196]
        recon_image = recon.view(1, 1, 14, 14)  # reshape to 14x14 image
        recon_resized = F.interpolate(recon_image, size=(28, 28), mode='bilinear').squeeze().cpu().numpy()

    axes[2, n].imshow(recon_resized, cmap='gray')
    axes[2, n].axis('off')
    #plt.savefig('CRBM_VAE_Reconstruction.pdf', format='pdf', bbox_inches='tight')
    plt.savefig('CRBM_VAE_Reconstruction.png')

plt.show()
